# %% [markdown]
# ### Understanding the loops concepts
# #### Python has two primitive loop commands:
# #### while loops
# #### for loops
# ### The while Loop
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
# while loop

counter = 5
while counter >= 0:
    print("loop count ",counter)
    counter=counter-1 
    # Note: remember to increment counter, or else the loop will continue forever.
# Out:
# loop count  5
# loop count  4
# loop count  3
# loop count  2
# loop count  1
# loop count  0

# %% [markdown]
# ### The break Statement
# With the break statement we can stop the loop even if the while condition is true:

# %%
i =0
while i <5:
    print(i)
    if i == 4:
        break
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### The continue Statement
# With the continue statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i <10:
    i+=1
    if i == 9:
        print("value is 9")
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# value is greater than 9
# 10

# %% [markdown]
# ### The else Statement
# With the else statement we can run a block of code once when the condition no longer is true:

# %%
# print message once the condition is flase
i = 1
while i < 5:
  print(i)
  i+=1
else:
  print("i is no longer less than 5")
# Out:
# 1
# 2
# 3
# 4
# i is no longer less than 5

# %%
# Create the i variable
i = 0
# While loop: print 1-5, skip 3 with continue
while i < 6:
    i+=1
    if i ==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
