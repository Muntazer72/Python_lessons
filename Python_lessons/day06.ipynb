# %% [markdown]
# ## Day 06 learning
# ### understanding Conditional statements

# %%
# contitional statement   are the piece of blocks executed depending on the situations

# condition
# conditional operators      are symbols  like +,_,<,>,*,/ and modulus and etc   which performs some operations
"""
contitional operators
> greater than
< less than
== equals
!=  not equals
>= greater than or equals
<= less than or equals

these gives ans in ture or false  e.g 12>5  is true
"""
print(12 > 5)
# we can also apply conditional operators on variables
 
value1 = 5
value2 = 10
print(value1<value2)
# Out:
# True
# True

# %%
# conditions
# if single
# if-else two block
# if-elif-else  multiblock

# if single
if 50>10:
    print("50 is greater than 10")  # if contidion is true the block will execute if not then block will not execute
    print("We are now inside the if block")
    # if condition if false then it does not execute the block inside if
# Out:
# 50 is greater than 10
# We are now inside the if block

# %% [markdown]
# ### Question:  Write a program to show marks and say  congratulations if marks are above 50 and show the percentage and marks in output also and total marks are 100

# %%
# only for understanding the working of the code
marks = float(input("Enter you marks: "))
if marks>50:
    print("Congratulations you are passed")
    percentage = marks/100*100
    print(f"Your marks are:{marks} and your percentage is: {percentage}")
print("You are fail Please try again next year")  
# this program dos not valid for multiple conditions
# Out:
# You are fail Please try again next year

# %%
# now alternative solution with efficeint working

marks = float(input("Enter you marks: "))
percentage = marks/100*100
if marks>50 and percentage>50:
    print(f" Congratulations You are passed!!!\n Your marks are:{marks} and your percentage is: {percentage}")
else:
    print("You are fail please try again next year")
# Out:
#  Congratulations You are passed!!!
#  Your marks are:100.0 and your percentage is: 100.0
