# %%
# understainding the input function

var1 = (input("Please enter first number: "))
var2= (input("Please enter first number: "))
sum = var1+var2
print(f"The sum of two numbers is: {sum}")
print( var1 , var2 , sum)
# Out:
# The sum of two numbers is: 2222
# 22 22 2222

# %% [markdown]
# ## There is a problem that is a logical error
# we just have to add the numeric values and first of all we have to solve this problem step by step
# #### step 01  Here we can print the values of variables
# print( var1 , var2 , sum)  it will shows the values which we have entered but the values of sum is not as we desired
# #### step 02  Here we have to find their data types
# print(type(var1))
# print(type(var2))
# print(type(sum))
# here it will show that these are strings values
# #### step 03  Here we have to convert the values into integer because calculations can be done on numeric values
# var1 = int(input("Please enter first number: "))
#
# var2= int(input("Please enter first number: "))
#
# sum = var1+var2
#
# print(f"The sum of two numbers is: {sum}")

# %%
# understainding the input function and type conversions

# write a code which input two numbers from user and print their sum

var1 = int(input("Please enter first number: "))
var2= int(input("Please enter first number: "))
sum = var1+var2
print(f"The sum of two numbers is: {sum}")
# Out:
# The sum of two numbers is: 22

# %%
# write a code which input two numbers from user and print multiply to output result

var1 = int(input("Please enter first number: "))
var2= int(input("Please enter first number: "))
mul = var1*var2
print(f"The multiplication of two numbers is: {mul}")
# Out:
# The multiplication of two numbers is: 4

# %%
#  type conversions from string to float

# write a code which input two numbers from user and print their difference

var1 = float(input("Please enter first number: "))
var2= float(input("Please enter first number: "))
differ = var1-var2
print(f"The sum of two numbers is: {differ}")
# Out:
# The sum of two numbers is: -1.0

# %%
# understainding the input function and type conversions

# write a code which input first name and last name from user and show their name

first_name = (input("Please enter first number: "))
last_name= (input("Please enter first number: "))
sum =  first_name,last_name
print(f"User name is: {first_name} {last_name}")
print(f"User first name is :{first_name}\nUser last name is: {last_name}")
# Out:
# User name is: Muntazer Mahdi
# User first name is :Muntazer
# User last name is: Mahdi

# %% [markdown]
# ### Built in functions
# import builtins
#
# dir(builtins)
#
# by entering this code you can find the builtin functions and can practice them

# %%
import builtins
dir(builtins)  # after running this code you can click on text editor then find all the functions
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# 1. abs()
#
# Use: Get positive value
# Use: Distance without direction
# 👉 Bank shows overdraft amount

# %%
abs(-500)
# Out:
# 500

# %% [markdown]
# 2. aiter()
#
# Use: Create async iterator
#
# Use: Read live chat messages (async stream)

# %%
async def numbers():
    for i in range(3):
        yield i

# %%
async def numbers():
    for i in range(3):
        yield i

async def main():
    async_iter = aiter(numbers())
    print(await anext(async_iter))
    print(await anext(async_iter))
    print(await anext(async_iter))

await main()   # ✅ instead of asyncio.run(main())
# Out:
# 0
# 1
# 2

# %% [markdown]
# 3. all()
#
# Use: Check if all students passed

# %%
all([True, True, True])  # True
# Out:
# True
